# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
tips = sns.load_dataset('tips')
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips[['total_bill', 'tip']].head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
tips[3:5]
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.loc[2:4, 'sex':'smoker']
# Out:
#       sex smoker
# 2    Male     No
# 3    Male     No
# 4  Female     No

# %%
tips.iloc[1:3, 0:2]
# Out:
#    total_bill   tip
# 1       10.34  1.66
# 2       21.01  3.50

# %%
tips[tips.tip > 1].head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
mi_tips = tips.groupby(['sex', 'smoker']).agg({'tip': 'mean'})
mi_tips
# Out:
#                     tip
# sex    smoker
# Male   Yes     3.051167
#        No      3.113402
# Female Yes     2.931515
#        No      2.773519

# %%
mi_tips.index
# Out:
# MultiIndex([(  'Male', 'Yes'),
#             (  'Male',  'No'),
#             ('Female', 'Yes'),
#             ('Female',  'No')],
#            names=['sex', 'smoker'])

# %%
mi_tips.loc[('Male', 'No')]
# Out:
# tip    3.113402
# Name: (Male, No), dtype: float64

# %%
ri_tips = mi_tips.reset_index()
ri_tips
# Out:
#       sex smoker       tip
# 0    Male    Yes  3.051167
# 1    Male     No  3.113402
# 2  Female    Yes  2.931515
# 3  Female     No  2.773519

# %%
ri_tips[(ri_tips.smoker == 'No') & (ri_tips.sex == 'Male')]
# Out:
#     sex smoker       tip
# 1  Male     No  3.113402

# %%
ri0_tips = mi_tips.reset_index(level=0)
ri0_tips.loc['Yes']
# Out:
#            sex       tip
# smoker
# Yes       Male  3.051167
# Yes     Female  2.931515

# %%
ri_tips.set_index(['sex', 'smoker'])
# Out:
#                     tip
# sex    smoker
# Male   Yes     3.051167
#        No      3.113402
# Female Yes     2.931515
#        No      2.773519

# %%
ri0_tips
# Out:
#            sex       tip
# smoker
# Yes       Male  3.051167
# No        Male  3.113402
# Yes     Female  2.931515
# No      Female  2.773519

# %%
ri0_tips.set_index('sex', append=True)
# Out:
#                     tip
# smoker sex
# Yes    Male    3.051167
# No     Male    3.113402
# Yes    Female  2.931515
# No     Female  2.773519

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips.at[0, 'total_bill'] = 9000
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0     9000.00  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
tips.iat[0,0]
# Out:
# 9000.0

# %%
# %%timeit
tips.at[0, 'total_bill'] = 6
# Out:
# 16.5 µs ± 76.4 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit
tips.loc['total_bill', 0] = 6
# Out:
# 68.4 µs ± 760 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
df = pd.DataFrame(np.random.randn(25).reshape((5,5)))
df.head()
# Out:
#           0         1         2         3         4
# 0 -0.393497  1.232896 -0.489600  1.451802  0.373626
# 1  0.976985 -0.581540  0.318791  0.005880  2.331265
# 2 -0.494084  0.140785  1.025155 -0.432072 -0.143274
# 3 -0.901952 -0.973479  0.181372 -1.273846 -0.416259
# 4 -1.340062 -0.558196  0.155829 -0.142074  1.500080

# %%
df.where(df>0)
# Out:
#           0         1         2         3         4
# 0       NaN  1.232896       NaN  1.451802  0.373626
# 1  0.976985       NaN  0.318791  0.005880  2.331265
# 2       NaN  0.140785  1.025155       NaN       NaN
# 3       NaN       NaN  0.181372       NaN       NaN
# 4       NaN       NaN  0.155829       NaN  1.500080

# %%
df[df<0] = np.NaN
df
# Out:
#           0         1         2         3         4
# 0       NaN  1.232896       NaN  1.451802  0.373626
# 1  0.976985       NaN  0.318791  0.005880  2.331265
# 2       NaN  0.140785  1.025155       NaN       NaN
# 3       NaN       NaN  0.181372       NaN       NaN
# 4       NaN       NaN  0.155829       NaN  1.500080
